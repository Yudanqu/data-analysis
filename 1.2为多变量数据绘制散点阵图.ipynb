# %%
# 加载库
from sklearn.datasets import load_iris
import numpy as np
import matplotlib.pyplot as plt
import itertools

# %% [markdown]
# 装载Iris数据集

# %%
data = load_iris()
x = data['data']
y = data['target']
col_names = data['feature_names']

# %% [markdown]
# 执行绘制一个简单的散点图过程

# %%
# 绘出6个图形，包括了以下几个列：花萼长度、花萼宽度、花瓣长度和花瓣宽度
plt.close('all') # 关掉其他的图像
plt.figure(1)

# 绘制一个3行2列的图
subplot_start = 321
col_numbers = range(0, 4)
# 为图形添加标签
col_pairs = itertools.combinations(col_numbers, 2)
plt.subplots_adjust(wspace = 0.5)

for col_pair in col_pairs:
    plt.subplot(subplot_start)
    plt.scatter(x[:,col_pair[0]], x[:,col_pair[1]], c=y)
    plt.xlabel(col_names[col_pair[0]])
    plt.ylabel(col_names[col_pair[1]])
    subplot_start += 1
    plt.show()

# %% [markdown]
# ## 原理

# %%
# scikit库提供了load_iris()函数方便的加载iris数据集
print(type(data))
data.keys()
# Out:
# <class 'sklearn.utils.Bunch'>
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %%
x.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %%
data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %% [markdown]
# 分析上述得到的数据集，data中的数据就是对应于这四个feature_names，目的是为了找到其中这两种花型的规律，方便以后根据他们的外形数据判断其种类。因此需要分别看看根据什么样的条件来分类，可以使判断时候更准确。

# %% [markdown]
# 共有四种属性，二维做起来很方便，分别两两取出来做分析，比较哪两个属性可以清晰的区分出这两种花型。
